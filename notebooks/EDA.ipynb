# %%
import os
import sys

# set the working dir to the parent working dir
current_working_dir = os.getcwd()
print(f'Previous working dir: {current_working_dir}')
new_working_dir = current_working_dir.replace('notebooks', '')
os.chdir(new_working_dir)
sys.path.insert(0, new_working_dir)
print(f'Current working dir: {os.getcwd()}')
# Out:
# Previous working dir: /home/albert/PycharmProjects/coupon/notebooks
# Current working dir: /home/albert/PycharmProjects/coupon

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
df = pd.read_csv('coupon_data.csv')
df.head(10)
# Out:
#    Unnamed: 0      destination  passanger weather  atmospheric_pressure  \
# 0           0  No Urgent Place      Alone   Sunny                101337
# 1           1  No Urgent Place  Friend(s)   Sunny                101328
# 2           2  No Urgent Place  Friend(s)   Sunny                101420
# 3           3  No Urgent Place  Friend(s)   Sunny                101392
# 4           4  No Urgent Place  Friend(s)   Sunny                101268
# 5           5  No Urgent Place  Friend(s)   Sunny                101379
# 6           6  No Urgent Place  Friend(s)   Sunny                101418
# 7           7  No Urgent Place     Kid(s)   Sunny                101378
# 8           8  No Urgent Place     Kid(s)   Sunny                101345
# 9           9  No Urgent Place     Kid(s)   Sunny                101385
#
#    yesterdays_temp  temperature  time                 coupon expiration  \
# 0               70           55   2PM        Restaurant(<20)         1d
# 1               50           80  10AM           Coffee House         2h
# 2               24           80  10AM  Carry out & Take away         2h
# 3               67           80   2PM           Coffee House         2h
# 4               54           80   2PM           Coffee House         1d
# 5               59           80   6PM        Restaurant(<20)         2h
# 6               63           55   2PM  Carry out & Take away         1d
# 7               27           80  10AM        Restaurant(<20)         2h
# 8               35           80  10AM  Carry out & Take away         2h
# 9               14           80  10AM                    Bar         1d
#
#    gender age      maritalStatus  has_children                 education  \
# 0  Female  21  Unmarried partner             1  Some college - no degree
# 1  Female  21  Unmarried partner             1  Some college - no degree
# 2  Female  21  Unmarried partner             1  Some college - no degree
# 3  Female  21  Unmarried partner             1  Some college - no degree
# 4  Female  21  Unmarried partner             1  Some college - no degree
# 5  Female  21  Unmarried partner             1  Some college - no degree
# 6  Female  21  Unmarried partner             1  Some college - no degree
# 7  Female  21  Unmarried partner             1  Some college - no degree
# 8  Female  21  Unmarried partner             1  Some college - no degree
# 9  Female  21  Unmarried partner             1  Some college - no degree
#
#    occupation           income  car    Bar CoffeeHouse CarryAway  \
# 0  Unemployed  $37500 - $49999  NaN  never       never       NaN
# 1  Unemployed  $37500 - $49999  NaN  never       never       NaN
# 2  Unemployed  $37500 - $49999  NaN  never       never       NaN
# 3  Unemployed  $37500 - $49999  NaN  never       never       NaN
# 4  Unemployed  $37500 - $49999  NaN  never       never       NaN
# 5  Unemployed  $37500 - $49999  NaN  never       never       NaN
# 6  Unemployed  $37500 - $49999  NaN  never       never       NaN
# 7  Unemployed  $37500 - $49999  NaN  never       never       NaN
# 8  Unemployed  $37500 - $49999  NaN  never       never       NaN
# 9  Unemployed  $37500 - $49999  NaN  never       never       NaN
#
#   RestaurantLessThan20 Restaurant20To50  toCoupon_GEQ5min  toCoupon_GEQ15min  \
# 0                  4~8              1~3                 1                  0
# 1                  4~8              1~3                 1                  0
# 2                  4~8              1~3                 1                  1
# 3                  4~8              1~3                 1                  1
# 4                  4~8              1~3                 1                  1
# 5                  4~8              1~3                 1                  1
# 6                  4~8              1~3                 1                  1
# 7                  4~8              1~3                 1                  1
# 8                  4~8              1~3                 1                  1
# 9                  4~8              1~3                 1                  1
#
#    toCoupon_GEQ25min  direction_same  direction_opp  Y
# 0                  0               0              1  1
# 1                  0               0              1  0
# 2                  0               0              1  1
# 3                  0               0              1  0
# 4                  0               0              1  0
# 5                  0               0              1  1
# 6                  0               0              1  1
# 7                  0               0              1  1
# 8                  0               0              1  1
# 9                  0               0              1  0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            12684 non-null  int64
#  1   destination           12684 non-null  object
#  2   passanger             12684 non-null  object
#  3   weather               12684 non-null  object
#  4   atmospheric_pressure  12684 non-null  int64
#  5   yesterdays_temp       12684 non-null  int64
#  6   temperature           12684 non-null  int64
#  7   time                  12684 non-null  object
#  8   coupon                12684 non-null  object
#  9   expiration            12684 non-null  object
#  10  gender                12684 non-null  object
#  11  age                   12684 non-null  object
#  12  maritalStatus         12684 non-null  object
#  13  has_children          12684 non-null  int64
#  14  education             12684 non-null  object
#  15  occupation            12684 non-null  object
#  16  income                12684 non-null  object
#  17  car                   108 non-null    object
#  18  Bar                   12577 non-null  object
#  19  CoffeeHouse           12467 non-null  object
#  20  CarryAway             12533 non-null  object
#  21  RestaurantLessThan20  12554 non-null  object
#  22  Restaurant20To50      12495 non-null  object
#  23  toCoupon_GEQ5min      12684 non-null  int64
#  24  toCoupon_GEQ15min     12684 non-null  int64
#  25  toCoupon_GEQ25min     12684 non-null  int64
#  26  direction_same        12684 non-null  int64
#  27  direction_opp         12684 non-null  int64
#  28  Y                     12684 non-null  int64
# dtypes: int64(11), object(18)
# memory usage: 2.8+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0  atmospheric_pressure  yesterdays_temp   temperature  \
# count  12684.000000          12684.000000     12684.000000  12684.000000
# mean    6341.500000         101324.201277        44.369126     63.301798
# std     3661.699742             57.803627        20.221734     19.154486
# min        0.000000         101225.000000        10.000000     30.000000
# 25%     3170.750000         101274.000000        27.000000     55.000000
# 50%     6341.500000         101324.000000        44.000000     80.000000
# 75%     9512.250000         101374.250000        62.000000     80.000000
# max    12683.000000         101424.000000        79.000000     80.000000
#
#        has_children  toCoupon_GEQ5min  toCoupon_GEQ15min  toCoupon_GEQ25min  \
# count  12684.000000           12684.0       12684.000000       12684.000000
# mean       0.414144               1.0           0.561495           0.119126
# std        0.492593               0.0           0.496224           0.323950
# min        0.000000               1.0           0.000000           0.000000
# 25%        0.000000               1.0           0.000000           0.000000
# 50%        0.000000               1.0           1.000000           0.000000
# 75%        1.000000               1.0           1.000000           0.000000
# max        1.000000               1.0           1.000000           1.000000
#
#        direction_same  direction_opp             Y
# count    12684.000000   12684.000000  12684.000000
# mean         0.214759       0.785241      0.568433
# std          0.410671       0.410671      0.495314
# min          0.000000       0.000000      0.000000
# 25%          0.000000       1.000000      0.000000
# 50%          0.000000       1.000000      1.000000
# 75%          0.000000       1.000000      1.000000
# max          1.000000       1.000000      1.000000

# %% [markdown]
# ### Show missing data
#
# #### conclusion:
# almost all data is missing from car column (12576/12684), hence this column should be deleted.
#
# a small amount of data is missing from Bar, CarryAway, RestaurantLessThan20 and Restaurant20To50. This rows can be deleted.

# %%
print(f'length: {len(df)}')
df.isnull().sum()
# Out:
# length: 12684
# Unnamed: 0                  0
# destination                 0
# passanger                   0
# weather                     0
# atmospheric_pressure        0
# yesterdays_temp             0
# temperature                 0
# time                        0
# coupon                      0
# expiration                  0
# gender                      0
# age                         0
# maritalStatus               0
# has_children                0
# education                   0
# occupation                  0
# income                      0
# car                     12576
# Bar                       107
# CoffeeHouse               217
# CarryAway                 151
# RestaurantLessThan20      130
# Restaurant20To50          189
# toCoupon_GEQ5min            0
# toCoupon_GEQ15min           0
# toCoupon_GEQ25min           0
# direction_same              0
# direction_opp               0
# Y                           0
# dtype: int64

# %% [markdown]
# # Delete rows and columns according to missing data

# %%
df.drop(columns='car', inplace=True)
df.dropna(inplace=True)

print(f'length: {len(df)}')
df.isnull().sum()
# Out:
# length: 12079
# Unnamed: 0              0
# destination             0
# passanger               0
# weather                 0
# atmospheric_pressure    0
# yesterdays_temp         0
# temperature             0
# time                    0
# coupon                  0
# expiration              0
# gender                  0
# age                     0
# maritalStatus           0
# has_children            0
# education               0
# occupation              0
# income                  0
# Bar                     0
# CoffeeHouse             0
# CarryAway               0
# RestaurantLessThan20    0
# Restaurant20To50        0
# toCoupon_GEQ5min        0
# toCoupon_GEQ15min       0
# toCoupon_GEQ25min       0
# direction_same          0
# direction_opp           0
# Y                       0
# dtype: int64

# %%
df.corr( )
# Out:
#                       Unnamed: 0  atmospheric_pressure  yesterdays_temp  \
# Unnamed: 0              1.000000             -0.018332        -0.004953
# atmospheric_pressure   -0.018332              1.000000         0.002674
# yesterdays_temp        -0.004953              0.002674         1.000000
# temperature            -0.368982              0.003408        -0.013571
# has_children           -0.010357              0.000333        -0.029498
# toCoupon_GEQ5min             NaN                   NaN              NaN
# toCoupon_GEQ15min      -0.026257             -0.000576         0.004689
# toCoupon_GEQ25min       0.035376              0.000117         0.013157
# direction_same          0.151727             -0.000572        -0.005674
# direction_opp          -0.151727              0.000572         0.005674
# Y                      -0.029003              0.001492         0.002650
#
#                       temperature  has_children  toCoupon_GEQ5min  \
# Unnamed: 0              -0.368982     -0.010357               NaN
# atmospheric_pressure     0.003408      0.000333               NaN
# yesterdays_temp         -0.013571     -0.029498               NaN
# temperature              1.000000     -0.020674               NaN
# has_children            -0.020674      1.000000               NaN
# toCoupon_GEQ5min              NaN           NaN               NaN
# toCoupon_GEQ15min       -0.155876      0.079735               NaN
# toCoupon_GEQ25min       -0.215780     -0.014038               NaN
# direction_same           0.097539     -0.033047               NaN
# direction_opp           -0.097539      0.033047               NaN
# Y                        0.056646     -0.048333               NaN
#
#                       toCoupon_GEQ15min  toCoupon_GEQ25min  direction_same  \
# Unnamed: 0                    -0.026257           0.035376        0.151727
# atmospheric_pressure          -0.000576           0.000117       -0.000572
# yesterdays_temp                0.004689           0.013157       -0.005674
# temperature                   -0.155876          -0.215780        0.097539
# has_children                   0.079735          -0.014038       -0.033047
# toCoupon_GEQ5min                    NaN                NaN             NaN
# toCoupon_GEQ15min              1.000000           0.325558       -0.305952
# toCoupon_GEQ25min              0.325558           1.000000       -0.192784
# direction_same                -0.305952          -0.192784        1.000000
# direction_opp                  0.305952           0.192784       -1.000000
# Y                             -0.081711          -0.100542        0.014361
#
#                       direction_opp         Y
# Unnamed: 0                -0.151727 -0.029003
# atmospheric_pressure       0.000572  0.001492
# yesterdays_temp            0.005674  0.002650
# temperature               -0.097539  0.056646
# has_children               0.033047 -0.048333
# toCoupon_GEQ5min                NaN       NaN
# toCoupon_GEQ15min          0.305952 -0.081711
# toCoupon_GEQ25min          0.192784 -0.100542
# direction_same            -1.000000  0.014361
# direction_opp              1.000000 -0.014361
# Y                         -0.014361  1.000000

# %% [markdown]
# ## Show categorical features
#
# #### conclusion:
# There are categorical features which are ordered and there are also unordered features.
# Ordered features should be represented by ordinal ints, unordered features should be represented by one-hot coding.
# ordered features:
# - time (7AM, 10AM, 2PM, 6PM, 10PM)
# - expiration (2h, 1d)
# - age (below21, 21, 26, 31, 36, 41, 46, 50plus)
# - education (Some High School, High School Graduate, Associates degree, Some college - no degree, Bachelors degree, Graduate degree (Masters or Doctorate))
# - income
# - (Bar (never, less1, 1~3, 4~8, gt8))
# - CoffeeHouse (never, less1, 1~3, 4~8, gt8)
# - CarryAway (never, less1, 1~3, 4~8, gt8)
# - RestaurantLessThan20 (never, less1, 1~3, 4~8, gt8)
# - Restaurant20To50 (never, less1, 1~3, 4~8, gt8)
#
#
# unordered features:
# - destination (3 class)
# - passenger (4 class)
# - weather (3 class)
# - coupon (5 class) : hybrid
# - gender (2 class)
# - maritalStatus (5 class)
# - occupation (25 class)
# - car (5 class)

# %%
import matplotlib.pyplot as plt

categoricals = df.select_dtypes(include=['object'])
fig, axes = plt.subplots(categoricals.shape[-1], 1, figsize=[10, 100])

for i in range(categoricals.shape[-1]):
    categoricals.iloc[:, i].value_counts().sort_index().plot(kind='bar', ax=axes[i], title=categoricals.columns[i])

# %%
print(f'length: {len(df)}')
categoricals = df.select_dtypes(include=['object'])
categoricals.nunique()
# Out:
# length: 12079
# destination              3
# passanger                4
# weather                  3
# time                     5
# coupon                   5
# expiration               2
# gender                   2
# age                      8
# maritalStatus            5
# education                6
# occupation              25
# income                   9
# Bar                      5
# CoffeeHouse              5
# CarryAway                5
# RestaurantLessThan20     5
# Restaurant20To50         5
# dtype: int64

# %%
categoricals.time.unique()
# Out:
# array(['2PM', '10AM', '6PM', '7AM', '10PM'], dtype=object)

# %% [markdown]
# # Change ordinal features to int

# %%
time_dict = {'7AM': 0, '10AM': 1, '2PM': 2, '6PM': 3, '10PM': 4} 
expiration_dict = {'2h': 0, '1d': 1}
age_dict = {'below21': 0, '21': 1, '26': 2, '31': 3, '36': 4, '41': 5, '46': 6, '50plus': 7}
education_dict = {'Some High School': 0, 'High School Graduate': 1, 'Associates degree': 2, 
             'Some college - no degree': 3, 'Bachelors degree': 4, 'Graduate degree (Masters or Doctorate)': 5}
income_dict = {'Less than $12500': 0, '$12500 - $24999': 1, '$25000 - $37499': 2, '$37500 - $49999': 3, 
          '$50000 - $62499': 4, '$62500 - $74999': 5,'$75000 - $87499': 6, '$87500 - $99999': 7, 
          '$100000 or More': 8}
bars_dict = {'never': 0, 'less1': 1, r'1~3': 2, r'4~8': 3, 'gt8': 4}

def make_ordinal(row):
    row.time = time_dict[row.time]
    row.expiration = expiration_dict[row.expiration]
    row.age = age_dict[row.age]
    row.education = education_dict[row.education]
    row.income = income_dict[row.income]
    row.Bar = bars_dict[row.Bar]
    row.CoffeeHouse = bars_dict[row.CoffeeHouse]
    row.CarryAway = bars_dict[row.CarryAway]
    row.RestaurantLessThan20 = bars_dict[row.RestaurantLessThan20]
    row.Restaurant20To50 = bars_dict[row.Restaurant20To50]
    
    return row

df = df.apply(make_ordinal, axis=1)

df.head(10)
# Out:
#     Unnamed: 0      destination  passanger weather  atmospheric_pressure  \
# 22          22  No Urgent Place      Alone   Sunny                101249
# 23          23  No Urgent Place  Friend(s)   Sunny                101342
# 24          24  No Urgent Place  Friend(s)   Sunny                101300
# 25          25  No Urgent Place  Friend(s)   Sunny                101404
# 26          26  No Urgent Place  Friend(s)   Sunny                101348
# 27          27  No Urgent Place  Friend(s)   Sunny                101257
# 28          28  No Urgent Place  Friend(s)   Sunny                101236
# 29          29  No Urgent Place  Friend(s)   Sunny                101398
# 30          30  No Urgent Place  Friend(s)   Sunny                101280
# 31          31  No Urgent Place  Friend(s)   Sunny                101226
#
#     yesterdays_temp  temperature  time                 coupon  expiration  \
# 22               19           55     2        Restaurant(<20)           1
# 23               51           80     1           Coffee House           0
# 24               76           80     1                    Bar           1
# 25               28           80     1  Carry out & Take away           0
# 26               72           80     2           Coffee House           1
# 27               26           80     2           Coffee House           0
# 28               25           80     2           Coffee House           1
# 29               50           80     2        Restaurant(<20)           1
# 30               36           80     3           Coffee House           0
# 31               78           80     3        Restaurant(<20)           0
#
#    gender  age maritalStatus  has_children  education  \
# 22   Male    1        Single             0          4
# 23   Male    1        Single             0          4
# 24   Male    1        Single             0          4
# 25   Male    1        Single             0          4
# 26   Male    1        Single             0          4
# 27   Male    1        Single             0          4
# 28   Male    1        Single             0          4
# 29   Male    1        Single             0          4
# 30   Male    1        Single             0          4
# 31   Male    1        Single             0          4
#
#                     occupation  income  Bar  CoffeeHouse  CarryAway  \
# 22  Architecture & Engineering       5    0            1          3
# 23  Architecture & Engineering       5    0            1          3
# 24  Architecture & Engineering       5    0            1          3
# 25  Architecture & Engineering       5    0            1          3
# 26  Architecture & Engineering       5    0            1          3
# 27  Architecture & Engineering       5    0            1          3
# 28  Architecture & Engineering       5    0            1          3
# 29  Architecture & Engineering       5    0            1          3
# 30  Architecture & Engineering       5    0            1          3
# 31  Architecture & Engineering       5    0            1          3
#
#     RestaurantLessThan20  Restaurant20To50  toCoupon_GEQ5min  \
# 22                     3                 1                 1
# 23                     3                 1                 1
# 24                     3                 1                 1
# 25                     3                 1                 1
# 26                     3                 1                 1
# 27                     3                 1                 1
# 28                     3                 1                 1
# 29                     3                 1                 1
# 30                     3                 1                 1
# 31                     3                 1                 1
#
#     toCoupon_GEQ15min  toCoupon_GEQ25min  direction_same  direction_opp  Y
# 22                  0                  0               0              1  1
# 23                  0                  0               0              1  0
# 24                  0                  0               0              1  1
# 25                  1                  0               0              1  0
# 26                  0                  0               0              1  0
# 27                  1                  0               0              1  0
# 28                  1                  0               0              1  0
# 29                  1                  0               0              1  1
# 30                  0                  0               0              1  0
# 31                  1                  0               0              1  1

# %% [markdown]
# # Change not ordinal features to one_hot

# %%
# - destination (3 class)
# - passenger (4 class)
# - weather (3 class)
# - coupon (5 class) : hybrid
# - gender (2 class)
# - maritalStatus (5 class)
# - occupation (25 class)
# - car (5 class)


categorical_variables = ['destination', 'passanger', 'weather', 'coupon', 'gender', 'maritalStatus', 
                         'occupation'] 
for variable in categorical_variables:
    discarded = pd.get_dummies(df[variable],prefix=variable)
    if discarded.shape[1] == 2:
        discarded = discarded.iloc[:, 0]
    df= pd.concat([df, discarded], axis = 1)
    df.drop([variable], axis = 1, inplace = True)

df.head(10)
# Out:
#     Unnamed: 0  atmospheric_pressure  yesterdays_temp  temperature  time  \
# 22          22                101249               19           55     2
# 23          23                101342               51           80     1
# 24          24                101300               76           80     1
# 25          25                101404               28           80     1
# 26          26                101348               72           80     2
# 27          27                101257               26           80     2
# 28          28                101236               25           80     2
# 29          29                101398               50           80     2
# 30          30                101280               36           80     3
# 31          31                101226               78           80     3
#
#     expiration  age  has_children  education  income  Bar  CoffeeHouse  \
# 22           1    1             0          4       5    0            1
# 23           0    1             0          4       5    0            1
# 24           1    1             0          4       5    0            1
# 25           0    1             0          4       5    0            1
# 26           1    1             0          4       5    0            1
# 27           0    1             0          4       5    0            1
# 28           1    1             0          4       5    0            1
# 29           1    1             0          4       5    0            1
# 30           0    1             0          4       5    0            1
# 31           0    1             0          4       5    0            1
#
#     CarryAway  RestaurantLessThan20  Restaurant20To50  toCoupon_GEQ5min  \
# 22          3                     3                 1                 1
# 23          3                     3                 1                 1
# 24          3                     3                 1                 1
# 25          3                     3                 1                 1
# 26          3                     3                 1                 1
# 27          3                     3                 1                 1
# 28          3                     3                 1                 1
# 29          3                     3                 1                 1
# 30          3                     3                 1                 1
# 31          3                     3                 1                 1
#
#     toCoupon_GEQ15min  toCoupon_GEQ25min  direction_same  direction_opp  Y  \
# 22                  0                  0               0              1  1
# 23                  0                  0               0              1  0
# 24                  0                  0               0              1  1
# 25                  1                  0               0              1  0
# 26                  0                  0               0              1  0
# 27                  1                  0               0              1  0
# 28                  1                  0               0              1  0
# 29                  1                  0               0              1  1
# 30                  0                  0               0              1  0
# 31                  1                  0               0              1  1
#
#     destination_Home  destination_No Urgent Place  destination_Work  \
# 22                 0                            1                 0
# 23                 0                            1                 0
# 24                 0                            1                 0
# 25                 0                            1                 0
# 26                 0                            1                 0
# 27                 0                            1                 0
# 28                 0                            1                 0
# 29                 0                            1                 0
# 30                 0                            1                 0
# 31                 0                            1                 0
#
#     passanger_Alone  passanger_Friend(s)  passanger_Kid(s)  passanger_Partner  \
# 22                1                    0                 0                  0
# 23                0                    1                 0                  0
# 24                0                    1                 0                  0
# 25                0                    1                 0                  0
# 26                0                    1                 0                  0
# 27                0                    1                 0                  0
# 28                0                    1                 0                  0
# 29                0                    1                 0                  0
# 30                0                    1                 0                  0
# 31                0                    1                 0                  0
#
#     weather_Rainy  weather_Snowy  weather_Sunny  coupon_Bar  \
# 22              0              0              1           0
# 23              0              0              1           0
# 24              0              0              1           1
# 25              0              0              1           0
# 26              0              0              1           0
# 27              0              0              1           0
# 28              0              0              1           0
# 29              0              0              1           0
# 30              0              0              1           0
# 31              0              0              1           0
#
#     coupon_Carry out & Take away  coupon_Coffee House  \
# 22                             0                    0
# 23                             0                    1
# 24                             0                    0
# 25                             1                    0
# 26                             0                    1
# 27                             0                    1
# 28                             0                    1
# 29                             0                    0
# 30                             0                    1
# 31                             0                    0
#
#     coupon_Restaurant(20-50)  coupon_Restaurant(<20)  gender_Female  \
# 22                         0                       1              0
# 23                         0                       0              0
# 24                         0                       0              0
# 25                         0                       0              0
# 26                         0                       0              0
# 27                         0                       0              0
# 28                         0                       0              0
# 29                         0                       1              0
# 30                         0                       0              0
# 31                         0                       1              0
#
#     maritalStatus_Divorced  maritalStatus_Married partner  \
# 22                       0                              0
# 23                       0                              0
# 24                       0                              0
# 25                       0                              0
# 26                       0                              0
# 27                       0                              0
# 28                       0                              0
# 29                       0                              0
# 30                       0                              0
# 31                       0                              0
#
#     maritalStatus_Single  maritalStatus_Unmarried partner  \
# 22                     1                                0
# 23                     1                                0
# 24                     1                                0
# 25                     1                                0
# 26                     1                                0
# 27                     1                                0
# 28                     1                                0
# 29                     1                                0
# 30                     1                                0
# 31                     1                                0
#
#     maritalStatus_Widowed  occupation_Architecture & Engineering  \
# 22                      0                                      1
# 23                      0                                      1
# 24                      0                                      1
# 25                      0                                      1
# 26                      0                                      1
# 27                      0                                      1
# 28                      0                                      1
# 29                      0                                      1
# 30                      0                                      1
# 31                      0                                      1
#
#     occupation_Arts Design Entertainment Sports & Media  \
# 22                                                  0
# 23                                                  0
# 24                                                  0
# 25                                                  0
# 26                                                  0
# 27                                                  0
# 28                                                  0
# 29                                                  0
# 30                                                  0
# 31                                                  0
#
#     occupation_Building & Grounds Cleaning & Maintenance  \
# 22                                                  0
# 23                                                  0
# 24                                                  0
# 25                                                  0
# 26                                                  0
# 27                                                  0
# 28                                                  0
# 29                                                  0
# 30                                                  0
# 31                                                  0
#
#     occupation_Business & Financial  occupation_Community & Social Services  \
# 22                                0                                       0
# 23                                0                                       0
# 24                                0                                       0
# 25                                0                                       0
# 26                                0                                       0
# 27                                0                                       0
# 28                                0                                       0
# 29                                0                                       0
# 30                                0                                       0
# 31                                0                                       0
#
#     occupation_Computer & Mathematical  occupation_Construction & Extraction  \
# 22                                   0                                     0
# 23                                   0                                     0
# 24                                   0                                     0
# 25                                   0                                     0
# 26                                   0                                     0
# 27                                   0                                     0
# 28                                   0                                     0
# 29                                   0                                     0
# 30                                   0                                     0
# 31                                   0                                     0
#
#     occupation_Education&Training&Library  \
# 22                                      0
# 23                                      0
# 24                                      0
# 25                                      0
# 26                                      0
# 27                                      0
# 28                                      0
# 29                                      0
# 30                                      0
# 31                                      0
#
#     occupation_Farming Fishing & Forestry  \
# 22                                      0
# 23                                      0
# 24                                      0
# 25                                      0
# 26                                      0
# 27                                      0
# 28                                      0
# 29                                      0
# 30                                      0
# 31                                      0
#
#     occupation_Food Preparation & Serving Related  \
# 22                                              0
# 23                                              0
# 24                                              0
# 25                                              0
# 26                                              0
# 27                                              0
# 28                                              0
# 29                                              0
# 30                                              0
# 31                                              0
#
#     occupation_Healthcare Practitioners & Technical  \
# 22                                                0
# 23                                                0
# 24                                                0
# 25                                                0
# 26                                                0
# 27                                                0
# 28                                                0
# 29                                                0
# 30                                                0
# 31                                                0
#
#     occupation_Healthcare Support  \
# 22                              0
# 23                              0
# 24                              0
# 25                              0
# 26                              0
# 27                              0
# 28                              0
# 29                              0
# 30                              0
# 31                              0
#
#     occupation_Installation Maintenance & Repair  occupation_Legal  \
# 22                                             0                 0
# 23                                             0                 0
# 24                                             0                 0
# 25                                             0                 0
# 26                                             0                 0
# 27                                             0                 0
# 28                                             0                 0
# 29                                             0                 0
# 30                                             0                 0
# 31                                             0                 0
#
#     occupation_Life Physical Social Science  occupation_Management  \
# 22                                        0                      0
# 23                                        0                      0
# 24                                        0                      0
# 25                                        0                      0
# 26                                        0                      0
# 27                                        0                      0
# 28                                        0                      0
# 29                                        0                      0
# 30                                        0                      0
# 31                                        0                      0
#
#     occupation_Office & Administrative Support  \
# 22                                           0
# 23                                           0
# 24                                           0
# 25                                           0
# 26                                           0
# 27                                           0
# 28                                           0
# 29                                           0
# 30                                           0
# 31                                           0
#
#     occupation_Personal Care & Service  occupation_Production Occupations  \
# 22                                   0                                  0
# 23                                   0                                  0
# 24                                   0                                  0
# 25                                   0                                  0
# 26                                   0                                  0
# 27                                   0                                  0
# 28                                   0                                  0
# 29                                   0                                  0
# 30                                   0                                  0
# 31                                   0                                  0
#
#     occupation_Protective Service  occupation_Retired  \
# 22                              0                   0
# 23                              0                   0
# 24                              0                   0
# 25                              0                   0
# 26                              0                   0
# 27                              0                   0
# 28                              0                   0
# 29                              0                   0
# 30                              0                   0
# 31                              0                   0
#
#     occupation_Sales & Related  occupation_Student  \
# 22                           0                   0
# 23                           0                   0
# 24                           0                   0
# 25                           0                   0
# 26                           0                   0
# 27                           0                   0
# 28                           0                   0
# 29                           0                   0
# 30                           0                   0
# 31                           0                   0
#
#     occupation_Transportation & Material Moving  occupation_Unemployed
# 22                                            0                      0
# 23                                            0                      0
# 24                                            0                      0
# 25                                            0                      0
# 26                                            0                      0
# 27                                            0                      0
# 28                                            0                      0
# 29                                            0                      0
# 30                                            0                      0
# 31                                            0                      0

# %% [markdown]
# ## Show continual features
#
# #### conclusion:
# All values are actually categorical.
#
#
# Categorizing toCoupons:
# toCoupon_GEQ5min has ones for every instance: everything is farther than 5 mins (although later we could encounter coupons which are closer than 5 min (<5 min). This will have 0 label.
# There are 5562 records where for neihter more than 15 or 25 mins far. As all toCoupon_GEQ5min is one, it means that these are 5< and <15 mins far (5<, <15 min). These will get 1 label.
# There are ... records which are coupons for more than 15 and but not more than 25 mins far (15<, <25 min). These will get 3 label.
# There are 1511 records which are coupons for both more than 15 and 25 mins far. As more than 25 mins far is also more than 15 mins far, these are actually more than 25 mins far (25< min). These will get 4 label.
#
#
#
# There are 0 records which are coupons for the same and opposite direction, which is ok, because these are excluding.
#
# There are 0 records which neighter coupons for the same or opposite direction, which is ok, as these are completive. Therefore these are redundant informations and one of them can be dropped (direction_opp).
#
# There are no big outliers. toCoupon_GEQ25min, direction_same/direction_opp  are imbalanced (11/2, 10/3).

# %%
import matplotlib.pyplot as plt

numericals = df.select_dtypes(include=['int64'])
fig, axes = plt.subplots(numericals.shape[-1], 1, figsize=[10, 100])

for i in range(numericals.shape[-1]):
    numericals.iloc[:, i].plot(kind='hist', bins=100, ax=axes[i], title=numericals.columns[i])

# %%
print(f'length: {len(df)}')

numericals = df.select_dtypes(include=['int64'])
numericals.nunique()
# Out:
# length: 12079
# Unnamed: 0              12079
# atmospheric_pressure      200
# yesterdays_temp            70
# temperature                 3
# time                        5
# expiration                  2
# age                         8
# has_children                2
# education                   6
# income                      9
# Bar                         5
# CoffeeHouse                 5
# CarryAway                   5
# RestaurantLessThan20        5
# Restaurant20To50            5
# toCoupon_GEQ5min            1
# toCoupon_GEQ15min           2
# toCoupon_GEQ25min           2
# direction_same              2
# direction_opp               2
# Y                           2
# dtype: int64

# %%
# are all toCoupon_GEQ5min 1?
dataset_length = len(df)
toCoupon_GEQ5min_1 = df.toCoupon_GEQ5min.sum()
print(f'Out of the {dataset_length} elements toCoupon_GEQ5min_1 == 1 {toCoupon_GEQ5min_1} times '
      '(it should not be the same as toCoupon_GEQ5min should not be 1 for all recordings).\n')

# are there datas with both toCoupon_GEQ15min and toCoupon_GEQ25min
both_15_and_25_min = (df.toCoupon_GEQ15min & df.toCoupon_GEQ25min).sum()
print(f'There are {both_15_and_25_min} records which are coupons for both 15 and 25 mins far, '
      '(it should be 0 as these are excluding).\n')

# are there datas with both toCoupon_GEQ15min and toCoupon_GEQ25min
is_15_not_25_min = (df.toCoupon_GEQ15min & (1-df.toCoupon_GEQ25min)).sum()
print(f'There are {is_15_not_25_min} records which are coupons for 15 but not 25 mins far, '
      '(it should be 0 as these are excluding).\n')

# are there datas with both toCoupon_GEQ15min and toCoupon_GEQ25min
not_15_is_25_min = ((1-df.toCoupon_GEQ15min) & df.toCoupon_GEQ25min).sum()
print(f'There are {not_15_is_25_min} records which are coupons for not 15 but 25 mins far, '
      '(it should be 0 as these are excluding).\n')

# are there datas with neighter toCoupon_GEQ15min and toCoupon_GEQ25min
neighter_15_and_25_min = ((1-df.toCoupon_GEQ15min) & (1-df.toCoupon_GEQ25min)).sum()
print(f'There are {neighter_15_and_25_min} records which are coupons for neighter 15 or 25 mins far, '
      '(if 0 these are completive and one of them can be dropped).\n')

# are there datas with both direction_same and direction_opp
both_same_and_opp_dir = (df.direction_same & df.direction_opp).sum()
print(f'There are {both_same_and_opp_dir} records which are coupons for the same and opposite direction, '
      '(it should be 0 as these are excluding).\n')

# are there datas neighter direction_same and direction_opp
neighter_same_and_opp_dir = ((1-df.direction_same) & (1-df.direction_opp)).sum()
print(f'There are {neighter_same_and_opp_dir} records which neighter coupons for the same or opposite direction, '
      '(it should be 0 as these are completive and one of them can be dropped).\n')
# Out:
# Out of the 12079 elements toCoupon_GEQ5min_1 == 1 12079 times (it should not be the same as toCoupon_GEQ5min should not be 1 for all recordings).
#
# There are 1442 records which are coupons for both 15 and 25 mins far, (it should be 0 as these are excluding).
#
# There are 5337 records which are coupons for 15 but not 25 mins far, (it should be 0 as these are excluding).
#
# There are 0 records which are coupons for not 15 but 25 mins far, (it should be 0 as these are excluding).
#
# There are 5300 records which are coupons for neighter 15 or 25 mins far, (if 0 these are completive and one of them can be dropped).
#
# There are 0 records which are coupons for the same and opposite direction, (it should be 0 as these are excluding).
#
# There are 0 records which neighter coupons for the same or opposite direction, (it should be 0 as these are completive and one of them can be dropped).

# %% [markdown]
# # Change the dataset according to the continual features

# %%
df.drop(columns='direction_opp', inplace=True)

def label_coupon_time(row):
    if not row['toCoupon_GEQ5min']:
        return 0
    if row['toCoupon_GEQ5min'] and not row['toCoupon_GEQ15min']:
        return 1
    if row['toCoupon_GEQ15min'] and not row['toCoupon_GEQ25min']:
        return 2
    if row['toCoupon_GEQ25min']:
        return 3
    else:
        return None

df['coupon_time'] = df.apply(label_coupon_time, axis=1)
df.drop(columns='toCoupon_GEQ5min', inplace=True)
df.drop(columns='toCoupon_GEQ15min', inplace=True)
df.drop(columns='toCoupon_GEQ25min', inplace=True)
df.head(100)
# Out:
#      Unnamed: 0  atmospheric_pressure  yesterdays_temp  temperature  time  \
# 22           22                101249               19           55     2
# 23           23                101342               51           80     1
# 24           24                101300               76           80     1
# 25           25                101404               28           80     1
# 26           26                101348               72           80     2
# ..          ...                   ...              ...          ...   ...
# 117         117                101361               79           80     2
# 118         118                101304               77           80     3
# 119         119                101343               55           80     3
# 120         120                101297               56           55     2
# 121         121                101278               10           55     2
#
#      expiration  age  has_children  education  income  Bar  CoffeeHouse  \
# 22            1    1             0          4       5    0            1
# 23            0    1             0          4       5    0            1
# 24            1    1             0          4       5    0            1
# 25            0    1             0          4       5    0            1
# 26            1    1             0          4       5    0            1
# ..          ...  ...           ...        ...     ...  ...          ...
# 117           1    2             0          4       4    2            4
# 118           0    2             0          4       4    2            4
# 119           0    2             0          4       4    2            4
# 120           0    2             0          4       4    2            4
# 121           1    2             0          4       4    2            4
#
#      CarryAway  RestaurantLessThan20  Restaurant20To50  direction_same  Y  \
# 22           3                     3                 1               0  1
# 23           3                     3                 1               0  0
# 24           3                     3                 1               0  1
# 25           3                     3                 1               0  0
# 26           3                     3                 1               0  0
# ..         ...                   ...               ...             ... ..
# 117          3                     2                 1               0  1
# 118          3                     2                 1               0  0
# 119          3                     2                 1               0  0
# 120          3                     2                 1               0  0
# 121          3                     2                 1               0  1
#
#      destination_Home  destination_No Urgent Place  destination_Work  \
# 22                  0                            1                 0
# 23                  0                            1                 0
# 24                  0                            1                 0
# 25                  0                            1                 0
# 26                  0                            1                 0
# ..                ...                          ...               ...
# 117                 0                            1                 0
# 118                 0                            1                 0
# 119                 0                            1                 0
# 120                 0                            1                 0
# 121                 0                            1                 0
#
#      passanger_Alone  passanger_Friend(s)  passanger_Kid(s)  \
# 22                 1                    0                 0
# 23                 0                    1                 0
# 24                 0                    1                 0
# 25                 0                    1                 0
# 26                 0                    1                 0
# ..               ...                  ...               ...
# 117                0                    1                 0
# 118                0                    1                 0
# 119                0                    1                 0
# 120                0                    1                 0
# 121                0                    1                 0
#
#      passanger_Partner  weather_Rainy  weather_Snowy  weather_Sunny  \
# 22                   0              0              0              1
# 23                   0              0              0              1
# 24                   0              0              0              1
# 25                   0              0              0              1
# 26                   0              0              0              1
# ..                 ...            ...            ...            ...
# 117                  0              0              0              1
# 118                  0              0              0              1
# 119                  0              0              0              1
# 120                  0              0              0              1
# 121                  0              0              0              1
#
#      coupon_Bar  coupon_Carry out & Take away  coupon_Coffee House  \
# 22            0                             0                    0
# 23            0                             0                    1
# 24            1                             0                    0
# 25            0                             1                    0
# 26            0                             0                    1
# ..          ...                           ...                  ...
# 117           0                             0                    0
# 118           0                             0                    1
# 119           0                             0                    0
# 120           0                             0                    1
# 121           0                             1                    0
#
#      coupon_Restaurant(20-50)  coupon_Restaurant(<20)  gender_Female  \
# 22                          0                       1              0
# 23                          0                       0              0
# 24                          0                       0              0
# 25                          0                       0              0
# 26                          0                       0              0
# ..                        ...                     ...            ...
# 117                         0                       1              0
# 118                         0                       0              0
# 119                         0                       1              0
# 120                         0                       0              0
# 121                         0                       0              0
#
#      maritalStatus_Divorced  maritalStatus_Married partner  \
# 22                        0                              0
# 23                        0                              0
# 24                        0                              0
# 25                        0                              0
# 26                        0                              0
# ..                      ...                            ...
# 117                       0                              0
# 118                       0                              0
# 119                       0                              0
# 120                       0                              0
# 121                       0                              0
#
#      maritalStatus_Single  maritalStatus_Unmarried partner  \
# 22                      1                                0
# 23                      1                                0
# 24                      1                                0
# 25                      1                                0
# 26                      1                                0
# ..                    ...                              ...
# 117                     0                                1
# 118                     0                                1
# 119                     0                                1
# 120                     0                                1
# 121                     0                                1
#
#      maritalStatus_Widowed  occupation_Architecture & Engineering  \
# 22                       0                                      1
# 23                       0                                      1
# 24                       0                                      1
# 25                       0                                      1
# 26                       0                                      1
# ..                     ...                                    ...
# 117                      0                                      0
# 118                      0                                      0
# 119                      0                                      0
# 120                      0                                      0
# 121                      0                                      0
#
#      occupation_Arts Design Entertainment Sports & Media  \
# 22                                                   0
# 23                                                   0
# 24                                                   0
# 25                                                   0
# 26                                                   0
# ..                                                 ...
# 117                                                  0
# 118                                                  0
# 119                                                  0
# 120                                                  0
# 121                                                  0
#
#      occupation_Building & Grounds Cleaning & Maintenance  \
# 22                                                   0
# 23                                                   0
# 24                                                   0
# 25                                                   0
# 26                                                   0
# ..                                                 ...
# 117                                                  0
# 118                                                  0
# 119                                                  0
# 120                                                  0
# 121                                                  0
#
#      occupation_Business & Financial  occupation_Community & Social Services  \
# 22                                 0                                       0
# 23                                 0                                       0
# 24                                 0                                       0
# 25                                 0                                       0
# 26                                 0                                       0
# ..                               ...                                     ...
# 117                                0                                       0
# 118                                0                                       0
# 119                                0                                       0
# 120                                0                                       0
# 121                                0                                       0
#
#      occupation_Computer & Mathematical  occupation_Construction & Extraction  \
# 22                                    0                                     0
# 23                                    0                                     0
# 24                                    0                                     0
# 25                                    0                                     0
# 26                                    0                                     0
# ..                                  ...                                   ...
# 117                                   0                                     0
# 118                                   0                                     0
# 119                                   0                                     0
# 120                                   0                                     0
# 121                                   0                                     0
#
#      occupation_Education&Training&Library  \
# 22                                       0
# 23                                       0
# 24                                       0
# 25                                       0
# 26                                       0
# ..                                     ...
# 117                                      0
# 118                                      0
# 119                                      0
# 120                                      0
# 121                                      0
#
#      occupation_Farming Fishing & Forestry  \
# 22                                       0
# 23                                       0
# 24                                       0
# 25                                       0
# 26                                       0
# ..                                     ...
# 117                                      0
# 118                                      0
# 119                                      0
# 120                                      0
# 121                                      0
#
#      occupation_Food Preparation & Serving Related  \
# 22                                               0
# 23                                               0
# 24                                               0
# 25                                               0
# 26                                               0
# ..                                             ...
# 117                                              0
# 118                                              0
# 119                                              0
# 120                                              0
# 121                                              0
#
#      occupation_Healthcare Practitioners & Technical  \
# 22                                                 0
# 23                                                 0
# 24                                                 0
# 25                                                 0
# 26                                                 0
# ..                                               ...
# 117                                                0
# 118                                                0
# 119                                                0
# 120                                                0
# 121                                                0
#
#      occupation_Healthcare Support  \
# 22                               0
# 23                               0
# 24                               0
# 25                               0
# 26                               0
# ..                             ...
# 117                              0
# 118                              0
# 119                              0
# 120                              0
# 121                              0
#
#      occupation_Installation Maintenance & Repair  occupation_Legal  \
# 22                                              0                 0
# 23                                              0                 0
# 24                                              0                 0
# 25                                              0                 0
# 26                                              0                 0
# ..                                            ...               ...
# 117                                             0                 0
# 118                                             0                 0
# 119                                             0                 0
# 120                                             0                 0
# 121                                             0                 0
#
#      occupation_Life Physical Social Science  occupation_Management  \
# 22                                         0                      0
# 23                                         0                      0
# 24                                         0                      0
# 25                                         0                      0
# 26                                         0                      0
# ..                                       ...                    ...
# 117                                        0                      0
# 118                                        0                      0
# 119                                        0                      0
# 120                                        0                      0
# 121                                        0                      0
#
#      occupation_Office & Administrative Support  \
# 22                                            0
# 23                                            0
# 24                                            0
# 25                                            0
# 26                                            0
# ..                                          ...
# 117                                           0
# 118                                           0
# 119                                           0
# 120                                           0
# 121                                           0
#
#      occupation_Personal Care & Service  occupation_Production Occupations  \
# 22                                    0                                  0
# 23                                    0                                  0
# 24                                    0                                  0
# 25                                    0                                  0
# 26                                    0                                  0
# ..                                  ...                                ...
# 117                                   0                                  0
# 118                                   0                                  0
# 119                                   0                                  0
# 120                                   0                                  0
# 121                                   0                                  0
#
#      occupation_Protective Service  occupation_Retired  \
# 22                               0                   0
# 23                               0                   0
# 24                               0                   0
# 25                               0                   0
# 26                               0                   0
# ..                             ...                 ...
# 117                              0                   0
# 118                              0                   0
# 119                              0                   0
# 120                              0                   0
# 121                              0                   0
#
#      occupation_Sales & Related  occupation_Student  \
# 22                            0                   0
# 23                            0                   0
# 24                            0                   0
# 25                            0                   0
# 26                            0                   0
# ..                          ...                 ...
# 117                           0                   1
# 118                           0                   1
# 119                           0                   1
# 120                           0                   1
# 121                           0                   1
#
#      occupation_Transportation & Material Moving  occupation_Unemployed  \
# 22                                             0                      0
# 23                                             0                      0
# 24                                             0                      0
# 25                                             0                      0
# 26                                             0                      0
# ..                                           ...                    ...
# 117                                            0                      0
# 118                                            0                      0
# 119                                            0                      0
# 120                                            0                      0
# 121                                            0                      0
#
#      coupon_time
# 22             1
# 23             1
# 24             1
# 25             2
# 26             1
# ..           ...
# 117            2
# 118            1
# 119            2
# 120            1
# 121            2
#
# [100 rows x 64 columns]

# %%
# feature importance
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

outputs = df.Y.to_numpy()
inputs_pd = df.drop(columns=['Y', 'Unnamed: 0'])
inputs = inputs_pd.to_numpy()

model = RandomForestClassifier(n_estimators=200, max_depth=5)
model.fit(inputs, outputs)

importance = model.feature_importances_
for i,(c, v) in enumerate(zip(inputs_pd.columns, importance)):
    print(f'Feature: {i} ({c}), Score: {v:.5f}')
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# Feature: 0 (atmospheric_pressure), Score: 0.00854
# Feature: 1 (yesterdays_temp), Score: 0.00657
# Feature: 2 (temperature), Score: 0.01500
# Feature: 3 (time), Score: 0.02504
# Feature: 4 (expiration), Score: 0.08900
# Feature: 5 (age), Score: 0.01237
# Feature: 6 (has_children), Score: 0.00554
# Feature: 7 (education), Score: 0.00873
# Feature: 8 (income), Score: 0.00911
# Feature: 9 (Bar), Score: 0.02970
# Feature: 10 (CoffeeHouse), Score: 0.08870
# Feature: 11 (CarryAway), Score: 0.00705
# Feature: 12 (RestaurantLessThan20), Score: 0.00432
# Feature: 13 (Restaurant20To50), Score: 0.01318
# Feature: 14 (direction_same), Score: 0.01026
# Feature: 15 (destination_Home), Score: 0.01410
# Feature: 16 (destination_No Urgent Place), Score: 0.04956
# Feature: 17 (destination_Work), Score: 0.00858
# Feature: 18 (passanger_Alone), Score: 0.01561
# Feature: 19 (passanger_Friend(s)), Score: 0.04930
# Feature: 20 (passanger_Kid(s)), Score: 0.00628
# Feature: 21 (passanger_Partner), Score: 0.00226
# Feature: 22 (weather_Rainy), Score: 0.01081
# Feature: 23 (weather_Snowy), Score: 0.01471
# Feature: 24 (weather_Sunny), Score: 0.02811
# Feature: 25 (coupon_Bar), Score: 0.08103
# Feature: 26 (coupon_Carry out & Take away), Score: 0.11923
# Feature: 27 (coupon_Coffee House), Score: 0.05250
# Feature: 28 (coupon_Restaurant(20-50)), Score: 0.02402
# Feature: 29 (coupon_Restaurant(<20)), Score: 0.09471
# Feature: 30 (gender_Female), Score: 0.00558
# Feature: 31 (maritalStatus_Divorced), Score: 0.00119
# Feature: 32 (maritalStatus_Married partner), Score: 0.00389
# Feature: 33 (maritalStatus_Single), Score: 0.01192
# Feature: 34 (maritalStatus_Unmarried partner), Score: 0.00131
# Feature: 35 (maritalStatus_Widowed), Score: 0.00071
# Feature: 36 (occupation_Architecture & Engineering), Score: 0.00106
# Feature: 37 (occupation_Arts Design Entertainment Sports & Media), Score: 0.00066
# Feature: 38 (occupation_Building & Grounds Cleaning & Maintenance), Score: 0.00008
# Feature: 39 (occupation_Business & Financial), Score: 0.00066
# Feature: 40 (occupation_Community & Social Services), Score: 0.00068
# Feature: 41 (occupation_Computer & Mathematical), Score: 0.00149
# Feature: 42 (occupation_Construction & Extraction), Score: 0.00080
# Feature: 43 (occupation_Education&Training&Library), Score: 0.00118
# Feature: 44 (occupation_Farming Fishing & Forestry), Score: 0.00014
# Feature: 45 (occupation_Food Preparation & Serving Related), Score: 0.00051
# Feature: 46 (occupation_Healthcare Practitioners & Technical), Score: 0.00225
# Feature: 47 (occupation_Healthcare Support), Score: 0.00147
# Feature: 48 (occupation_Installation Maintenance & Repair), Score: 0.00088
# Feature: 49 (occupation_Legal), Score: 0.00174
# Feature: 50 (occupation_Life Physical Social Science), Score: 0.00055
# Feature: 51 (occupation_Management), Score: 0.00076
# Feature: 52 (occupation_Office & Administrative Support), Score: 0.00090
# Feature: 53 (occupation_Personal Care & Service), Score: 0.00054
# Feature: 54 (occupation_Production Occupations), Score: 0.00088
# Feature: 55 (occupation_Protective Service), Score: 0.00043
# Feature: 56 (occupation_Retired), Score: 0.00310
# Feature: 57 (occupation_Sales & Related), Score: 0.00188
# Feature: 58 (occupation_Student), Score: 0.00336
# Feature: 59 (occupation_Transportation & Material Moving), Score: 0.00062
# Feature: 60 (occupation_Unemployed), Score: 0.00290
# Feature: 61 (coupon_time), Score: 0.04197

# %%
from sklearn.feature_selection import RFE

# rfe = RFE(estimator=RandomForestClassifier(max_depth=5), n_features_to_select=15)
# selector = rfe.fit(inputs, outputs)
# selected_inputs = inputs[:, selector.support_]

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(inputs, outputs, test_size=0.33, random_state=42)

model = RandomForestClassifier(n_estimators=500, n_jobs=-1, max_features=0.5, max_depth=20, 
                               random_state=0, criterion='gini')
model.fit(X_train, y_train)

accuracy_score(y_test, model.predict(X_test))
# Out:
# 0.7434161023325809
